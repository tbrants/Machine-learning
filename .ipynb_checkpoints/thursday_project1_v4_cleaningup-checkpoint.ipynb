# %% [markdown]
# - I believe RMSE is not a very important value in CLASSIFICATION. We should look more at accuracy and F1

# %% [markdown]
# # INDEX
# - 1) Test methods individually by hand to see errors in them - **OKAY**
# - 2) Apply cross validtion to see if results are consistent with only one run of the method (done in 1)) - **OKAY**
# - 3) Find good hyperparameters for each method "automatically" using cross validation - **OKAY**
# - 4) Feature modification and compare results with previous runs
# - 5) Add new feature modification (logs and 3 groups of -999s maybe)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from functions import *
dirname = os.path.dirname('__file__')
DATA_TRAIN_PATH = os.path.join(dirname, 'data/train.csv')
y, tx, ids = load_csv_data(DATA_TRAIN_PATH)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1) Tested methods with different parameters by hand and in cross validation. I want good accuracy mainly
# - **least_squares_GD:** the more iters the greater the rmse error, gamma should be around 1e-6, initial weights better if ones than zeros. F1 ~ 0.41 and A ~ 0.63 . Cross validation is consistent. rmse is in the order of 5e63. With large gammas (1e-5 and 20 maxiters) it breaks. Later i got better results with zeros. Mystery.
#
# - **least_squares_SGD:** for big gammas (0.1) and many iters (80) the SGD gives an invalid value for matmul, i dunno why. Accuracy, F1 and rmse change a lot depending on the run without changing the parameters, between 0.36 an 0.65 the accuracy is jumping, so doesnt look very reliable, you can really see it in the cross validation accuracy prints. rmse is in the order of 5e56
#
# - **least_squares:** very nice. Gives F1 ~ 0.57 and accuracy ~ 0.74 always, as can be seen in the cross validation prints. rmse is 0.82.
#
# - **ridge_regression:** when the penalization is small you get higher values for F1 and accuracy~0.74 (lambda=0.01) but when they are bigger (lambda=1000), the results get a liiittle bit worse: accuracy around 0.69 and F1 also falls from 0.53 to 0.31. In this method rmse is very small, around 0.85. Same for cross validation.
#
# - **logistic_regression_gd:** gamma desnt do anthing interesting, neither does iters or the initial weights. F1~ 0.36 and acc~0.66. the rmse_lr is 4e4 *negative* btw. Sometimes there is a warning that "there is an overflow in the sigmoid function" but then you run it again and disappears. Cross validation has the same results approx.
#
# - **logistic_regression_reg:** the gamma doesnt do much, but lamda decreases the accuracy from 0.66 to 0.31 when going from lambda=0.1 to 100. initial weights dont do anything, or maxiters. F1 gets higher with higher lambdas, from 0.36 to 0.4. The rmse is positive 1e17. Cross-v says the same.

# %%
w, loss = least_squares_GD(y, tx, np.zeros(tx.shape[1]), 20, 0.0000001)
y_pred = predict_labels(w, tx)
f1_value = f1(y, y_pred)
acc_value = accuracy(y, y_pred)
# Out:
# Gradient Descent: RMSE is  0.9257609262143314
# TP =  31895 ; FP =  36047 ; TN =  128286 ; FN =  53772
# F1 = 0.4152751466385433
# Accuracy = 0.640724

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
first_obser = range(50)

ax.scatter(first_obser,y[0:50],s=12, label='Real y')
ax.scatter(first_obser,y_pred[0:50],s=12, label='Predicted y')
ax.title.set_text('Predicted vs. real (50 samples)')
ax.text(2,0.3,'RMSE = '+str(loss))
ax.text(2,0.15, 'F1 = '+ str(f1_value))
ax.text(2,0,'accuracy = '+str(acc_value))
leg = ax.legend();
plt.show()

# %% [markdown]
# # 2) Cross validation returns
# - weights
# - rmse train
# - rmse test
# - F1
# - Accuracy

# %%
degree = 6
call_cross_validation(y, tx, k=3, degree=degree, seed=2, opt_method=least_squares, initial_w=np.ones(tx.shape[1]  * degree + 1), max_iters=20, gamma=0.0000001, lambda_=10)
# Out:
# least_squares
# Least squares: RMSE is  0.7640967127539745
# TP =  18478 ; FP =  6699 ; TN =  48050 ; FN =  10106
# F1 = 0.6874128085415077
# Accuracy = 0.7983391933567734
# least_squares
# Least squares: RMSE is  0.7974925513425275
# TP =  17546 ; FP =  7135 ; TN =  47607 ; FN =  11045
# F1 = 0.6587325424237873
# Accuracy = 0.7818391273565094
# least_squares
# Least squares: RMSE is  0.7640967127539745
# TP =  18478 ; FP =  6699 ; TN =  48050 ; FN =  10106
# F1 = 0.6874128085415077
# Accuracy = 0.7983391933567734
# (array([-3.34852664e+05,  2.99735367e-02,  5.01547741e-03,  8.86030948e-03,
#         -3.53562206e-03, -2.96440422e-02, -3.53426006e-03, -8.49831305e-02,
#         -2.37643156e+00, -8.64707280e-04, -1.91947649e+00, -2.32634924e-01,
#         -1.36813189e-01, -7.59913284e-01,  1.96991270e+00, -3.20568632e-03,
#         -5.85727357e-03,  1.94202297e+00, -1.22067204e-03,  1.13987145e-03,
#         -7.84520977e-03, -2.70192714e-03,  2.61321156e-03, -1.85443511e+06,
#          1.84911190e-02,  4.73456760e-02, -2.61787995e-02,  1.49013895e-02,
#         -4.43587022e-03,  6.13093556e-02,  1.91534340e+00, -1.43416835e-04,
#         -3.39884155e-04, -1.60021865e-04,  3.77814611e-05, -8.26650634e-04,
#          6.12273435e-06, -3.25580378e-03,  2.59327178e+00, -1.74843494e-05,
#          2.71074688e-05,  1.58174024e-01,  8.54146461e-04,  1.08518415e+00,
#         -7.12786996e-04,  4.27715884e-04,  3.28005484e-04, -5.39038384e-04,
#         -2.82351629e-02, -3.59791752e-04,  2.23120696e-04,  4.29185113e-04,
#         -9.32164533e-06,  1.66489392e+06, -1.75684790e-04,  4.08734433e-02,
#         -6.14260392e-04, -1.01921882e-04,  3.39647216e-02, -2.92897857e-03,
#         -2.17848590e-05,  2.14235194e-07,  3.40842502e-06,  7.45891533e-07,
#         -2.17622238e-07,  2.94458414e-03, -5.11629077e-09,  7.99273472e-04,
#         -1.25353748e+00,  5.83255138e-07, -5.71605782e-08, -3.30859936e-02,
#          2.45261266e-01,  7.84480225e-03,  4.41551893e-06,  7.17402079e-04,
#          1.44771629e-03,  4.84381333e-06,  1.04488668e-04, -6.34787075e-04,
#         -1.80440542e-06,  6.82203686e-04,  5.66133667e-09,  1.44030338e+05,
#          8.90996688e-07, -6.23480547e-03,  4.26478390e-03,  3.39013116e-07,
#          8.67379735e-04, -1.03158168e-02,  6.61505721e-08,  1.08088779e-11,
#         -1.29489049e-08, -1.44131383e-09,  5.76573409e-10, -1.25274099e-06,
#          2.13876669e-12,  5.76367403e-06,  3.05539991e-01, -3.53831862e-09,
#          6.21355176e-11,  3.13483281e-03,  3.20064902e-02, -8.27457550e-06,
#         -1.37770274e-08, -9.15793092e-03, -7.62983339e-04, -2.13537638e-08,
#         -2.93376045e-03, -5.71211702e-04,  6.47549721e-09,  4.02503719e-04,
#          1.09566395e-11, -4.20085736e+05, -2.35337587e-09, -6.39422017e-06,
#          1.08582780e-06, -4.54606819e-10,  1.54331658e-07,  6.54840231e-06,
#         -1.02038862e-10, -2.45180096e-13,  2.08210810e-11,  1.22366470e-12,
#         -7.15786539e-13, -2.97675869e-09, -4.24331633e-16, -6.23259700e-09,
#         -3.63693135e-02,  7.68319381e-12, -3.06614220e-14, -1.39213579e-04,
#         -7.58831273e-02, -1.15586302e-09,  2.05492244e-11, -1.06093848e-04,
#         -9.04914013e-05,  4.46817749e-11, -9.88929631e-05,  3.62138436e-05,
#         -1.03383380e-11, -4.25902527e-05, -1.49289412e-14,  1.03599912e+05,
#          3.03750211e-12, -5.38294085e-09,  1.78815680e-09, -5.40040175e-14,
#         -7.86069536e-10,  1.30084106e-08,  7.32843513e-14,  1.34306615e-16,
#         -1.19189748e-14, -3.78077626e-16,  3.30943305e-16,  1.60353370e-12,
#          3.15973468e-20,  9.68209315e-12,  1.70540030e-03, -5.53725119e-15,
#          5.17304223e-18,  2.35207462e-06, -1.11069909e-02,  2.69361164e-12,
#         -1.15040736e-14,  1.02280759e-03,  7.83086679e-05, -3.52964732e-14,
#          3.86666697e-04,  6.08976125e-05,  5.96202598e-15, -5.74736258e-05,
#          4.77434754e-18, -5.65506712e+03, -1.49890212e-15,  6.07417055e-12,
#         -6.73174929e-12,  3.91535429e-16, -9.08055440e-13, -1.24207620e-11,
#         -1.90045235e-17]),
#  0.7752286589501588,
#  0.9848289990281128,
#  0.6778527198356009,
#  0.7928391713566855)

# %% [markdown]
# # 3) Find good hyperparameters automatically, i didnt do initial weights

# %% [markdown]
# # gradient descent: max_iters, gamma

# %%
lambdas = [0]
gammas = [1e-11, 1e-9,1e-7,1e-6]
degrees = [0, 2, 4, 6, 8]
max_iterations =  [1,5,10,15,20]
pd_filled_GD = hyperparameter_tuning(y,tx,3,2,least_squares_GD,np.ones(tx.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# least_squares_GD
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f103bafabb01> in <module>
#       3 degrees = [0, 2, 4, 6, 8]
#       4 max_iterations =  [1,5,10,15,20]
# ----> 5 pd_filled_GD = hyperparameter_tuning(y,tx,3,2,least_squares_GD,np.ones(tx.shape[1]),max_iterations,degrees,gammas,lambdas)
#
# ~\Documents\Documenten EPFL\Machine Learning\Machine-learning\functions.py in hyperparameter_tuning(y, tx, k, seed, meth, initw, max_iterations, degrees, gammas, lambdas)
#     321                                                          ma,
#     322                                                          ga,
# --> 323                                                          lam)
#     324                     dictio = {'max_iters':ma,'lambda':lam,'gamma':ga,'degree':deg,'out_w':w, 'rmse_tr':rmse_tr, 'rmse_te':rmse_te, 'f1':f1, 'acc':acc}
#     325                     pd_filled = pd_filled.append(dictio, ignore_index=True)
#
# ~\Documents\Documenten EPFL\Machine Learning\Machine-learning\functions.py in call_cross_validation(y, x, k, degree, seed, opt_method, initial_w, max_iters, gamma, lambda_)
#     236         if opt_method == least_squares_GD:
#     237             print('least_squares_GD')
# --> 238             w, loss = opt_method(y_train, phi_train, initial_w, max_iters, gamma)
#     239
#     240         elif opt_method == least_squares_SGD:
#
# ~\Documents\Documenten EPFL\Machine Learning\Machine-learning\functions.py in least_squares_GD(y, tx, initial_w, max_iters, gamma)
#      92     w = initial_w
#      93     for n_iter in range(max_iters):
# ---> 94         grad = compute_gradient(y, tx, w)
#      95         w -= gamma*grad
#      96     loss = compute_loss(y, tx, w)
#
# ~\Documents\Documenten EPFL\Machine Learning\Machine-learning\functions.py in compute_gradient(y, tx, w)
#      83 def compute_gradient(y, tx, w):
#      84     N = len(y)
# ---> 85     e = compute_error(y, tx, w)
#      86     grad = (-1/N)*np.matmul(tx.T,e)
#      87     return grad
#
# ~\Documents\Documenten EPFL\Machine Learning\Machine-learning\functions.py in compute_error(y, tx, w)
#      69 " MACHINE LEARNING METHODS"
#      70 def compute_error(y, tx, w):
# ---> 71     e = y-np.matmul(tx, w)
#      72     return e
#      73
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 30 is different from 1)

# %%
#find parameters that maximize accuracy
pd.DataFrame(pd_filled_GD.loc[pd_filled_GD['acc'].idxmax()])
# Out:
#                                                           17
# acc                                                 0.631511
# degree                                                     0
# f1                                                  0.413789
# gamma                                                  1e-06
# lambda                                                     0
# max_iters                                                 10
# out_w      [7.187721762988187e+26, -3.607983224050016e+26...
# rmse_te                                          1.54465e+31
# rmse_tr                                          1.54379e+31

# %%
accuracies = list(pd_filled_GD['acc'].values) 
paint=np.zeros((len(max_iterations),len(gammas)))
k = -1
for i in range(len(max_iterations)):
    for j in range(len(gammas)):
        paint[i][j]=accuracies[k]
        k+=1
plt.figure(figsize=(4,4))
sns.heatmap(paint,xticklabels=gammas[::-1], yticklabels=max_iterations[::-1])
plt.xlabel('Gammas')
plt.ylabel('Max iterations')
plt.title('Accuracy gradient descent')
plt.show()

# %%
#find parameters that maximize F1
pd.DataFrame(pd_filled_GD.loc[pd_filled_GD['f1'].idxmax()])
# Out:
#                                                           12
# acc                                                 0.507634
# degree                                                     0
# f1                                                   0.53585
# gamma                                                  1e-07
# lambda                                                     0
# max_iters                                                 10
# out_w      [0.3219404593597527, 1.0017213530640157, 0.932...
# rmse_te                                              506.759
# rmse_tr                                              506.264

# %%
#find parameters that minimize rmse_train
pd.DataFrame(pd_filled_GD.loc[pd_filled_GD['rmse_tr'].idxmin()])
# Out:
#                                                           15
# acc                                                 0.455302
# degree                                                     0
# f1                                                  0.392926
# gamma                                                  1e-06
# lambda                                                     0
# max_iters                                                  1
# out_w      [0.04823167876813176, 0.9313223786573701, 0.78...
# rmse_te                                              180.376
# rmse_tr                                              180.785

# %%
#find parameters that minimize rmse_test
pd.DataFrame(pd_filled_GD.loc[pd_filled_GD['rmse_te'].idxmin()])
# Out:
#                                                           15
# acc                                                 0.455302
# degree                                                     0
# f1                                                  0.392926
# gamma                                                  1e-06
# lambda                                                     0
# max_iters                                                  1
# out_w      [0.04823167876813176, 0.9313223786573701, 0.78...
# rmse_te                                              180.376
# rmse_tr                                              180.785

# %% [markdown]
# # stochastic gradient descent: max_iters, gamma

# %%
lambdas = [0]
gammas = [1e-9, 1e-7, 1e-6]
degrees = [0]
max_iterations =  [10,20]
pd_filled_SGD = hyperparameter_tuning(y,tx,3,2,least_squares_SGD,np.ones(tx.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  5745.0905396672
# (83333, 30)
# TP =  10812 ; FP =  13314 ; TN =  41435 ; FN =  17772
# F1 = 0.4102447353443369
# Accuracy = 0.6269665078660315
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  5449.229183706126
# (83333, 30)
# TP =  10753 ; FP =  13149 ; TN =  41678 ; FN =  17753
# F1 = 0.4103571973744467
# Accuracy = 0.6291745166980668
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  4862.330570828235
# (83333, 30)
# TP =  10838 ; FP =  13162 ; TN =  41735 ; FN =  17598
# F1 = 0.4133801205278816
# Accuracy = 0.630878523514094
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  6854.130225901818
# (83333, 30)
# TP =  10797 ; FP =  13182 ; TN =  41417 ; FN =  17937
# F1 = 0.4096522679414945
# Accuracy = 0.6265705062820252
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  6048.889282340766
# (83333, 30)
# TP =  10837 ; FP =  13221 ; TN =  41468 ; FN =  17807
# F1 = 0.4112557398201207
# Accuracy = 0.6276625106500426
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  6363.089399140552
# (83333, 30)
# TP =  10888 ; FP =  13193 ; TN =  41594 ; FN =  17658
# F1 = 0.41377999885990074
# Accuracy = 0.6297865191460765
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  670.0500630944755
# (83333, 30)
# TP =  27787 ; FP =  45296 ; TN =  9467 ; FN =  783
# F1 = 0.5467029994195941
# Accuracy = 0.4470497881991528
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  35.28564843653464
# (83333, 30)
# TP =  27886 ; FP =  49466 ; TN =  5308 ; FN =  673
# F1 = 0.5265930828714676
# Accuracy = 0.39832959331837325
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  151.0206604595415
# (83333, 30)
# TP =  25588 ; FP =  40945 ; TN =  13927 ; FN =  2873
# F1 = 0.5387287618165357
# Accuracy = 0.4741818967275869
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  4.091008968777032
# (83333, 30)
# TP =  18614 ; FP =  26976 ; TN =  27740 ; FN =  10003
# F1 = 0.5016777392968318
# Accuracy = 0.5562502250009
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  891.6619756060352
# (83333, 30)
# TP =  15906 ; FP =  24097 ; TN =  30782 ; FN =  12548
# F1 = 0.46470046890748934
# Accuracy = 0.5602582410329642
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  304.7741014048179
# (83333, 30)
# TP =  25243 ; FP =  40919 ; TN =  13830 ; FN =  3341
# F1 = 0.5328562683385051
# Accuracy = 0.46887787551150206
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  886648870.6436236
# (83333, 30)
# TP =  10775 ; FP =  13384 ; TN =  41453 ; FN =  17721
# F1 = 0.40926787579527113
# Accuracy = 0.6267385069540278
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  2840000452875147.0
# (83333, 30)
# TP =  10660 ; FP =  12103 ; TN =  42769 ; FN =  17801
# F1 = 0.41621115102295797
# Accuracy = 0.6411505646022584
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  1.2367401152601597e+23
# (83333, 30)
# TP =  17767 ; FP =  41351 ; TN =  13365 ; FN =  10850
# F1 = 0.4050151022966889
# Accuracy = 0.37358549434197735
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  8.589810204377249e+36
# (83333, 30)
# TP =  10345 ; FP =  12456 ; TN =  42238 ; FN =  18294
# F1 = 0.40221617418351474
# Accuracy = 0.630998523994096
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  2.184830777600664e+47
# (83333, 30)
# TP =  20286 ; FP =  45409 ; TN =  9407 ; FN =  8231
# F1 = 0.430645777607948
# Accuracy = 0.35631742526970106
# least_squares_SGD
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# (1, 30)
# Stochastic Gradient Descent: RMSE is  1.4258762217843435e+61
# (83333, 30)
# TP =  10747 ; FP =  12035 ; TN =  42752 ; FN =  17799
# F1 = 0.4187577930174563
# Accuracy = 0.6419905679622718

# %%
#find parameters that maximize accuracy
pd.DataFrame(pd_filled_SGD.loc[pd_filled_SGD['acc'].idxmax()])
# Out:
#                                                            0
# acc                                                 0.629007
# degree                                                     0
# f1                                                  0.411327
# gamma                                                  1e-09
# lambda                                                     0
# max_iters                                                 10
# out_w      [0.9981815923242666, 1.0096110214644962, 1.013...
# rmse_te                                              6204.57
# rmse_tr                                              5352.22

# %%
accuracies = list(pd_filled_SGD['acc'].values) 
paint=np.zeros((len(max_iterations),len(gammas)))
k = -1
for i in range(len(max_iterations)):
    for j in range(len(gammas)):
        paint[i][j]=accuracies[k]
        k+=1
plt.figure(figsize=(4,4))
sns.heatmap(paint,xticklabels=gammas[::-1], yticklabels=max_iterations[::-1])
plt.xlabel('Gammas')
plt.ylabel('Max iterations')
plt.title('Accuracy stochastic gradient descent')
plt.show()

# %% [markdown]
# # least squares: nothing

# %%
lambdas = [0]
gammas = [0]
degrees = [0]
max_iterations =  [0]
pd_filled_LS = hyperparameter_tuning(y,tx,3,2,least_squares,np.ones(tx.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# least_squares
# (166666, 30)
# Least squares: RMSE is  0.8236501712263041
# (83333, 30)
# TP =  13934 ; FP =  6892 ; TN =  47871 ; FN =  14636
# F1 = 0.5641752368612843
# Accuracy = 0.7416629666518666
# least_squares
# (166666, 30)
# Least squares: RMSE is  0.8239615512140147
# (83333, 30)
# TP =  13958 ; FP =  6867 ; TN =  48030 ; FN =  14478
# F1 = 0.5666957633827978
# Accuracy = 0.7438589754359017
# least_squares
# (166666, 30)
# Least squares: RMSE is  0.8236304812160452
# (83333, 30)
# TP =  13964 ; FP =  6945 ; TN =  47892 ; FN =  14532
# F1 = 0.5652869142799312
# Accuracy = 0.7422749690998764

# %%
#find parameters that maximize accuracy
pd.DataFrame(pd_filled_LS.loc[pd_filled_LS['acc'].idxmax()])
# Out:
#                                                            0
# acc                                                 0.742599
# degree                                                     0
# f1                                                  0.565386
# gamma                                                      0
# lambda                                                     0
# max_iters                                                  0
# out_w      [7.941543940587693e-05, -0.007244968849194809,...
# rmse_te                                             0.825355
# rmse_tr                                             0.823747

# %% [markdown]
# # ridge regression: lambda_

# %%
lambdas = [0.1,0.5,1,10,20]
gammas = [0]
degrees = [0]
max_iterations =  [0]
pd_filled_RR = hyperparameter_tuning(y,tx,3,2,ridge_regression,np.ones(tx.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8315887650904659
# (83333, 30)
# TP =  13550 ; FP =  6956 ; TN =  47982 ; FN =  14845
# F1 = 0.5541808960961944
# Accuracy = 0.7383869535478141
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8307139316558719
# (83333, 30)
# TP =  13621 ; FP =  6852 ; TN =  47810 ; FN =  15050
# F1 = 0.5543301318573987
# Accuracy = 0.7371749486997948
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.831139620607131
# (83333, 30)
# TP =  13614 ; FP =  6686 ; TN =  47892 ; FN =  15141
# F1 = 0.5550504535725206
# Accuracy = 0.7380749522998092
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8381118245808529
# (83333, 30)
# TP =  13140 ; FP =  6689 ; TN =  47926 ; FN =  15578
# F1 = 0.5413310812202609
# Accuracy = 0.7327949311797247
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8387551345133263
# (83333, 30)
# TP =  13131 ; FP =  6620 ; TN =  48122 ; FN =  15460
# F1 = 0.5432543130197345
# Accuracy = 0.7350389401557607
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8384860690638121
# (83333, 30)
# TP =  13225 ; FP =  6770 ; TN =  47979 ; FN =  15359
# F1 = 0.5444739496490253
# Accuracy = 0.7344509378037513
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8410690121090798
# (83333, 30)
# TP =  12969 ; FP =  6518 ; TN =  48224 ; FN =  15622
# F1 = 0.5394983152377387
# Accuracy = 0.7343189372757492
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8408550690035169
# (83333, 30)
# TP =  13091 ; FP =  6684 ; TN =  48065 ; FN =  15493
# F1 = 0.5414090448520441
# Accuracy = 0.733874935499742
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8410690121090798
# (83333, 30)
# TP =  12969 ; FP =  6518 ; TN =  48224 ; FN =  15622
# F1 = 0.5394983152377387
# Accuracy = 0.7343189372757492
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8447278558859017
# (83333, 30)
# TP =  12606 ; FP =  6308 ; TN =  48441 ; FN =  15978
# F1 = 0.5308012968967114
# Accuracy = 0.732566930267721
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8448434020734129
# (83333, 30)
# TP =  12453 ; FP =  6170 ; TN =  48572 ; FN =  16138
# F1 = 0.527513025797433
# Accuracy = 0.7323029292117168
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8447278558859017
# (83333, 30)
# TP =  12606 ; FP =  6308 ; TN =  48441 ; FN =  15978
# F1 = 0.5308012968967114
# Accuracy = 0.732566930267721
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8455320157669252
# (83333, 30)
# TP =  12159 ; FP =  5924 ; TN =  48818 ; FN =  16432
# F1 = 0.5210181257231006
# Accuracy = 0.7317269269077076
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8454395534561359
# (83333, 30)
# TP =  12238 ; FP =  6005 ; TN =  48744 ; FN =  16346
# F1 = 0.522689901125419
# Accuracy = 0.7317869271477085
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.8455320157669252
# (83333, 30)
# TP =  12159 ; FP =  5924 ; TN =  48818 ; FN =  16432
# F1 = 0.5210181257231006
# Accuracy = 0.7317269269077076

# %%
#find parameters that maximize accuracy
pd.DataFrame(pd_filled_RR.loc[pd_filled_RR['acc'].idxmax()])
# Out:
#                                                            0
# acc                                                 0.737879
# degree                                                     0
# f1                                                   0.55452
# gamma                                                      0
# lambda                                                   0.1
# max_iters                                                  0
# out_w      [0.000199646307917533, -0.008423971362052939, ...
# rmse_te                                             0.831841
# rmse_tr                                             0.831147

# %%
accuracies = list(pd_filled_RR['acc'].values) 
plt.plot(lambdas,accuracies)
plt.ylabel('Accuracy')
plt.xlabel('lambdas')
plt.title('Accuracy ridge regression')
plt.show()

# %% [markdown]
# # logistic regression gradient descent: max_iters, gamma

# %%
lambdas = [0]
gammas = [1e-9,1e-7,1e-6,1e-5]
degrees = [0]
max_iterations =  [10,15,30]
pd_filled_LRGD = hyperparameter_tuning(y,tx,3,2,logistic_regression_gd,np.ones(tx.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# logistic_regression_gd
# GD Logistic Regression: RMSE is  52207.85692335421
# (83333, 30)
# TP =  10793 ; FP =  13060 ; TN =  41689 ; FN =  17791
# F1 = 0.41165589183210327
# Accuracy = 0.6297865191460765
# logistic_regression_gd
# GD Logistic Regression: RMSE is  36755.18835483538
# (83333, 30)
# TP =  10855 ; FP =  12661 ; TN =  42081 ; FN =  17736
# F1 = 0.41664267756731344
# Accuracy = 0.6352345409381638
# logistic_regression_gd
# GD Logistic Regression: RMSE is  14516.811000611633
# (83333, 30)
# TP =  10766 ; FP =  12615 ; TN =  42134 ; FN =  17818
# F1 = 0.4143558164148947
# Accuracy = 0.6348025392101568
# logistic_regression_gd
# GD Logistic Regression: RMSE is  7145.674200528767
# (83333, 30)
# TP =  10818 ; FP =  12301 ; TN =  42441 ; FN =  17773
# F1 = 0.41841036549990335
# Accuracy = 0.6391105564422258
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -6218.025883975555
# (83333, 30)
# TP =  10736 ; FP =  12338 ; TN =  42411 ; FN =  17848
# F1 = 0.4156568198536528
# Accuracy = 0.6377665510662043
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -4476.555932679446
# (83333, 30)
# TP =  10800 ; FP =  12185 ; TN =  42557 ; FN =  17791
# F1 = 0.41879944160074456
# Accuracy = 0.6402865611462446
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -13437.809414742165
# (83333, 30)
# TP =  10719 ; FP =  12253 ; TN =  42496 ; FN =  17865
# F1 = 0.4158196912095586
# Accuracy = 0.6385825543302173
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -16871.35732421023
# (83333, 30)
# TP =  10748 ; FP =  12044 ; TN =  42698 ; FN =  17843
# F1 = 0.41834848101512173
# Accuracy = 0.6413545654182616
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -52430.582102331915
# (83333, 30)
# TP =  10381 ; FP =  11669 ; TN =  43080 ; FN =  18203
# F1 = 0.4100406841252914
# Accuracy = 0.6415345661382645
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -319852.6039301142
# (83333, 30)
# TP =  8110 ; FP =  7414 ; TN =  47328 ; FN =  20481
# F1 = 0.36767539385696474
# Accuracy = 0.6652586610346441
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -328093.64638858935
# (83333, 30)
# TP =  7955 ; FP =  7513 ; TN =  47236 ; FN =  20629
# F1 = 0.36116407881594476
# Accuracy = 0.6622946491785967
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -323920.6679392839
# (83333, 30)
# TP =  8079 ; FP =  7351 ; TN =  47391 ; FN =  20512
# F1 = 0.3670520887758115
# Accuracy = 0.6656426625706503
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -329849.12941291294
# (83333, 30)
# TP =  7946 ; FP =  7485 ; TN =  47264 ; FN =  20638
# F1 = 0.3610587299784164
# Accuracy = 0.6625226500906004
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324577.1400271437
# (83333, 30)
# TP =  8078 ; FP =  7340 ; TN =  47402 ; FN =  20513
# F1 = 0.3671067281692381
# Accuracy = 0.6657626630506522
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330460.8677202746
# (83333, 30)
# TP =  7943 ; FP =  7469 ; TN =  47280 ; FN =  20641
# F1 = 0.3610782798436222
# Accuracy = 0.6626786507146029
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324855.78852944437
# (83333, 30)
# TP =  8076 ; FP =  7334 ; TN =  47408 ; FN =  20515
# F1 = 0.3670825663053112
# Accuracy = 0.6658106632426529
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330697.65898894286
# (83333, 30)
# TP =  7943 ; FP =  7460 ; TN =  47289 ; FN =  20641
# F1 = 0.3611521585923114
# Accuracy = 0.6627866511466046
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324682.1141665743
# (83333, 30)
# TP =  8077 ; FP =  7335 ; TN =  47407 ; FN =  20514
# F1 = 0.36711133331818285
# Accuracy = 0.6658106632426529
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330398.0211779295
# (83333, 30)
# TP =  7946 ; FP =  7469 ; TN =  47280 ; FN =  20638
# F1 = 0.36119002704606923
# Accuracy = 0.6627146508586035
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324664.68745395215
# (83333, 30)
# TP =  8077 ; FP =  7335 ; TN =  47407 ; FN =  20514
# F1 = 0.36711133331818285
# Accuracy = 0.6658106632426529
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330687.9439586005
# (83333, 30)
# TP =  7944 ; FP =  7462 ; TN =  47287 ; FN =  20640
# F1 = 0.36117299386224144
# Accuracy = 0.6627746510986043
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324692.3191729826
# (83333, 30)
# TP =  8077 ; FP =  7335 ; TN =  47407 ; FN =  20514
# F1 = 0.36711133331818285
# Accuracy = 0.6658106632426529
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330715.882340646
# (83333, 30)
# TP =  7944 ; FP =  7460 ; TN =  47289 ; FN =  20640
# F1 = 0.36118941529508053
# Accuracy = 0.6627986511946048
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324623.2417433858
# (83333, 30)
# TP =  8077 ; FP =  7335 ; TN =  47407 ; FN =  20514
# F1 = 0.36711133331818285
# Accuracy = 0.6658106632426529
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330674.4313564931
# (83333, 30)
# TP =  7944 ; FP =  7463 ; TN =  47286 ; FN =  20640
# F1 = 0.36116478370575794
# Accuracy = 0.6627626510506042
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324595.02681038156
# (83333, 30)
# TP =  8078 ; FP =  7336 ; TN =  47406 ; FN =  20513
# F1 = 0.36714009771616857
# Accuracy = 0.6658106632426529
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330715.8823471226
# (83333, 30)
# TP =  7944 ; FP =  7461 ; TN =  47288 ; FN =  20640
# F1 = 0.3611812043920071
# Accuracy = 0.6627866511466046
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324899.551974545
# (83333, 30)
# TP =  8076 ; FP =  7332 ; TN =  47410 ; FN =  20515
# F1 = 0.36709925225573314
# Accuracy = 0.6658346633386534
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330715.88261673774
# (83333, 30)
# TP =  7944 ; FP =  7461 ; TN =  47288 ; FN =  20640
# F1 = 0.3611812043920071
# Accuracy = 0.6627866511466046
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324637.05725494376
# (83333, 30)
# TP =  8077 ; FP =  7334 ; TN =  47408 ; FN =  20514
# F1 = 0.3671196763783464
# Accuracy = 0.6658226632906532
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330646.8047826582
# (83333, 30)
# TP =  7944 ; FP =  7461 ; TN =  47288 ; FN =  20640
# F1 = 0.3611812043920071
# Accuracy = 0.6627866511466046
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324609.4262318278
# (83333, 30)
# TP =  8078 ; FP =  7335 ; TN =  47407 ; FN =  20513
# F1 = 0.3671484410508135
# Accuracy = 0.6658226632906532
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330757.32887512184
# (83333, 30)
# TP =  7944 ; FP =  7461 ; TN =  47288 ; FN =  20640
# F1 = 0.3611812043920071
# Accuracy = 0.6627866511466046
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324733.7658358495
# (83333, 30)
# TP =  8077 ; FP =  7333 ; TN =  47409 ; FN =  20514
# F1 = 0.3671280198177314
# Accuracy = 0.6658346633386534
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -330729.6978520059
# (83333, 30)
# TP =  7944 ; FP =  7459 ; TN =  47290 ; FN =  20640
# F1 = 0.3611976265714871
# Accuracy = 0.662810651242605
# logistic_regression_gd
# GD Logistic Regression: RMSE is  -324609.4262318278
# (83333, 30)
# TP =  8077 ; FP =  7335 ; TN =  47407 ; FN =  20514
# F1 = 0.36711133331818285
# Accuracy = 0.6658106632426529

# %%
#find parameters that maximize accuracy
pd.DataFrame(pd_filled_LRGD.loc[pd_filled_LRGD['acc'].idxmax()])
# Out:
#                                                           11
# acc                                                 0.664819
# degree                                                     0
# f1                                                  0.365146
# gamma                                                  1e-05
# lambda                                                     0
# max_iters                                                 30
# out_w      [26682.353045998436, -10212.347568627823, -123...
# rmse_te                                          4.89575e+08
# rmse_tr                                              -326691

# %%
accuracies = list(pd_filled_LRGD['acc'].values) 
paint=np.zeros((len(max_iterations),len(gammas)))
k = -1
for i in range(len(max_iterations)):
    for j in range(len(gammas)):
        paint[i][j]=accuracies[k]
        k+=1
plt.figure(figsize=(4,4))
sns.heatmap(paint,xticklabels=gammas[::-1], yticklabels=max_iterations[::-1])
plt.xlabel('Gammas')
plt.ylabel('Max iterations')
plt.title('Accuracy logistic regression gradient descent')
plt.show()

# %% [markdown]
# # regularized logistic regression: max_iters, gamma, lambda_

# %%
lambdas = [0.1,1,100]
gammas = [1e-9,1e-7,1e-5]
degrees = [0]
max_iterations =  [10,20,30]
pd_filled_LRRR = hyperparameter_tuning(y,tx,3,2,logistic_regression_reg,np.ones(tx.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  52211.70736221329
# (83333, 30)
# TP =  10793 ; FP =  13060 ; TN =  41689 ; FN =  17791
# F1 = 0.41165589183210327
# Accuracy = 0.6297865191460765
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  36760.25429983547
# (83333, 30)
# TP =  10855 ; FP =  12661 ; TN =  42081 ; FN =  17736
# F1 = 0.41664267756731344
# Accuracy = 0.6352345409381638
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  14523.473139588923
# (83333, 30)
# TP =  10766 ; FP =  12615 ; TN =  42134 ; FN =  17818
# F1 = 0.4143558164148947
# Accuracy = 0.6348025392101568
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  4252.254389494435
# (83333, 30)
# TP =  10810 ; FP =  12271 ; TN =  42471 ; FN =  17781
# F1 = 0.4184084223564019
# Accuracy = 0.63937455749823
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  -9080.359411712625
# (83333, 30)
# TP =  10732 ; FP =  12309 ; TN =  42440 ; FN =  17852
# F1 = 0.4157675544794189
# Accuracy = 0.6380665522662091
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  -6875.327137089888
# (83333, 30)
# TP =  10793 ; FP =  12159 ; TN =  42583 ; FN =  17798
# F1 = 0.4187959567739557
# Accuracy = 0.6405145620582482
# logistic_regression_reg
# Reg Logistic Regression: RMSE is
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  26002045505882.223
# (83333, 30)
# TP =  8078 ; FP =  7336 ; TN =  47406 ; FN =  20513
# F1 = 0.36714009771616857
# Accuracy = 0.6658106632426529
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  26685787349062.023
# (83333, 30)
# TP =  7941 ; FP =  7457 ; TN =  47292 ; FN =  20643
# F1 = 0.36110226911009047
# Accuracy = 0.6627986511946048
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  27336515266488.016
# (83333, 30)
# TP =  8078 ; FP =  7336 ; TN =  47406 ; FN =  20513
# F1 = 0.36714009771616857
# Accuracy = 0.6658106632426529
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  28300564212104.746
# (83333, 30)
# TP =  7941 ; FP =  7459 ; TN =  47290 ; FN =  20643
# F1 = 0.3610858493997817
# Accuracy = 0.6627746510986043
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  29201376476763.406
# (83333, 30)
# TP =  8078 ; FP =  7336 ; TN =  47406 ; FN =  20513
# F1 = 0.36714009771616857
# Accuracy = 0.6658106632426529
# logistic_regression_reg
# Reg Logistic Regression: RMSE is  30085221622126.676
# (83333, 30)
# TP =  7941 ; FP =  7459 ; TN =  47290 ; FN =  20643
# F1 = 0.3610858493997817
# Accuracy = 0.6627746510986043

# %%
#find parameters that maximize accuracy
pd.DataFrame(pd_filled_LRRR.loc[pd_filled_LRRR['acc'].idxmax()])
# Out:
#                                                            7
# acc                                                 0.664811
# degree                                                     0
# f1                                                  0.365121
# gamma                                                  1e-05
# lambda                                                   0.1
# max_iters                                                 20
# out_w      [13373.432657336705, -5118.697492643271, -6190...
# rmse_te                                          2.29562e+08
# rmse_tr                                          9.96334e+08

# %% [markdown]
# # 4) Feature modification and compare results with previous runs

# %% [markdown]
# Only doing the example for the best case, ridge regression accuracy  ~ 0.74. Could have also been least squares, which is similar

# %%
# MANIPULATE MISSING VALUES

# %%
tx_999 = manipulate_missing_values(tx)

# %%
tx_999.shape
# Out:
# (250000, 30)

# %%
lambdas = [0.5,1,10,20]
gammas = [0]
degrees = [0, 1, 2, 3]
max_iterations =  [0]
pd_filled_RR = hyperparameter_tuning(y,tx_999,3,2,ridge_regression,np.ones(tx_999.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9069896920946815
# (83333, 30)
# TP =  6456 ; FP =  2687 ; TN =  52055 ; FN =  22135
# F1 = 0.34218476705358564
# Accuracy = 0.7021348085392342
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9067067047627023
# (83333, 30)
# TP =  6333 ; FP =  2702 ; TN =  52047 ; FN =  22251
# F1 = 0.33669156543236134
# Accuracy = 0.700562802251209
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9069896920946815
# (83333, 30)
# TP =  6456 ; FP =  2687 ; TN =  52055 ; FN =  22135
# F1 = 0.34218476705358564
# Accuracy = 0.7021348085392342
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9071236049323891
# (83333, 30)
# TP =  6285 ; FP =  2658 ; TN =  52091 ; FN =  22299
# F1 = 0.3349588296426573
# Accuracy = 0.7005148020592082
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9073641801772918
# (83333, 30)
# TP =  6406 ; FP =  2654 ; TN =  52088 ; FN =  22185
# F1 = 0.340283126610183
# Accuracy = 0.7019308077232309
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9071236049323891
# (83333, 30)
# TP =  6285 ; FP =  2658 ; TN =  52091 ; FN =  22299
# F1 = 0.3349588296426573
# Accuracy = 0.7005148020592082
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9080033798209353
# (83333, 30)
# TP =  6188 ; FP =  2502 ; TN =  52240 ; FN =  22403
# F1 = 0.3319653442772458
# Accuracy = 0.7011388045552183
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.907823169073795
# (83333, 30)
# TP =  6051 ; FP =  2470 ; TN =  52279 ; FN =  22533
# F1 = 0.3261555046489692
# Accuracy = 0.6999627998511994
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9080033798209353
# (83333, 30)
# TP =  6188 ; FP =  2502 ; TN =  52240 ; FN =  22403
# F1 = 0.3319653442772458
# Accuracy = 0.7011388045552183
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9081379851715247
# (83333, 30)
# TP =  5880 ; FP =  2352 ; TN =  52397 ; FN =  22704
# F1 = 0.31942633637548895
# Accuracy = 0.6993267973071893
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9083215255851588
# (83333, 30)
# TP =  6000 ; FP =  2361 ; TN =  52381 ; FN =  22591
# F1 = 0.3247456159341849
# Accuracy = 0.7005748022992092
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9081379851715247
# (83333, 30)
# TP =  5880 ; FP =  2352 ; TN =  52397 ; FN =  22704
# F1 = 0.31942633637548895
# Accuracy = 0.6993267973071893

# %%
#find parameters that maximize accuracy
pd.DataFrame(pd_filled_RR.loc[pd_filled_RR['acc'].idxmax()])
# Out:
#                                                            0
# acc                                                 0.701611
# degree                                                     0
# f1                                                  0.340354
# gamma                                                      0
# lambda                                                   0.5
# max_iters                                                  0
# out_w      [0.0022206090674363253, -0.006331557669508957,...
# rmse_te                                             0.907176
# rmse_tr                                             0.906895

# %%
accuracies = list(pd_filled_RR['acc'].values) 
plt.plot(lambdas,accuracies)
plt.ylabel('Accuracy')
plt.xlabel('lambdas')
plt.title('Accuracy ridge regression')
plt.show()

# %%
# NORMALIZE FEATURES

# %%
tx_stand = standardize_features(tx_999)

# %%
lambdas = [0.5,1,10,20]
gammas = [0]
degrees = [0]
max_iterations =  [0]
pd_filled_RR = hyperparameter_tuning(y,tx_stand,3,2,ridge_regression,np.ones(tx_stand.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9623614292177954
# (83333, 30)
# TP =  8917 ; FP =  6119 ; TN =  48623 ; FN =  19674
# F1 = 0.4087835514704197
# Accuracy = 0.6904827619310477
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.961934089758167
# (83333, 30)
# TP =  8859 ; FP =  6199 ; TN =  48550 ; FN =  19725
# F1 = 0.40598506026304926
# Accuracy = 0.6889107556430226
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9623614292177954
# (83333, 30)
# TP =  8917 ; FP =  6119 ; TN =  48623 ; FN =  19674
# F1 = 0.4087835514704197
# Accuracy = 0.6904827619310477
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.96706125282316
# (83333, 30)
# TP =  8762 ; FP =  6249 ; TN =  48500 ; FN =  19822
# F1 = 0.40197270329166185
# Accuracy = 0.6871467485869943
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9674203304022914
# (83333, 30)
# TP =  8823 ; FP =  6157 ; TN =  48585 ; FN =  19768
# F1 = 0.4049941474834179
# Accuracy = 0.6888987555950223
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.96706125282316
# (83333, 30)
# TP =  8762 ; FP =  6249 ; TN =  48500 ; FN =  19822
# F1 = 0.40197270329166185
# Accuracy = 0.6871467485869943
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9903091208949433
# (83333, 30)
# TP =  8789 ; FP =  6558 ; TN =  48184 ; FN =  19802
# F1 = 0.4000637261595885
# Accuracy = 0.6836787347149389
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9902058672426745
# (83333, 30)
# TP =  8747 ; FP =  6626 ; TN =  48123 ; FN =  19837
# F1 = 0.39797984393839436
# Accuracy = 0.6824427297709191
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9903091208949433
# (83333, 30)
# TP =  8789 ; FP =  6558 ; TN =  48184 ; FN =  19802
# F1 = 0.4000637261595885
# Accuracy = 0.6836787347149389
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9944690589895341
# (83333, 30)
# TP =  8758 ; FP =  6715 ; TN =  48034 ; FN =  19826
# F1 = 0.39757586762602987
# Accuracy = 0.6815067260269041
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9945258810362566
# (83333, 30)
# TP =  8805 ; FP =  6628 ; TN =  48114 ; FN =  19786
# F1 = 0.40000908595311646
# Accuracy = 0.6830307321229285
# ridge_regression
# (166666, 30)
# Ridge Regression: RMSE is  0.9944690589895341
# (83333, 30)
# TP =  8758 ; FP =  6715 ; TN =  48034 ; FN =  19826
# F1 = 0.39757586762602987
# Accuracy = 0.6815067260269041

# %%
tx_bal, y_bal = balance_data(tx_stand, y, 0.5)
# Out:
# Before balancing
# 85667 (34.27)% 1 labels in training data
# 164333 (65.73)% -1 labels in training data
# After balancing
# 85667 (50.00)% 1 labels in training data
# 85667 (50.00)% -1 labels in training data

# %%
lambdas = [0.5,1,10,20]
gammas = [0]
degrees = [0]
max_iterations =  [0]
pd_filled_RR = hyperparameter_tuning(y_bal,tx_bal,3,2,ridge_regression,np.ones(tx_bal.shape[1]),max_iterations,degrees,gammas,lambdas)
# Out:
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9605579105519731
# (57111, 30)
# TP =  9019 ; FP =  3250 ; TN =  25214 ; FN =  19628
# F1 = 0.44085443347345776
# Accuracy = 0.599411672007144
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9610730493812389
# (57111, 30)
# TP =  8938 ; FP =  3089 ; TN =  25303 ; FN =  19781
# F1 = 0.438717910960585
# Accuracy = 0.5995517501006812
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9606373509818962
# (57111, 30)
# TP =  8894 ; FP =  3133 ; TN =  25483 ; FN =  19601
# F1 = 0.4389714229307537
# Accuracy = 0.6019330776908126
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9648253401913279
# (57111, 30)
# TP =  8789 ; FP =  3285 ; TN =  25352 ; FN =  19685
# F1 = 0.43351090066094505
# Accuracy = 0.5978007739314668
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9649465882521949
# (57111, 30)
# TP =  8798 ; FP =  3227 ; TN =  25375 ; FN =  19711
# F1 = 0.43410470222529235
# Accuracy = 0.5983610863056154
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9658343134448463
# (57111, 30)
# TP =  8893 ; FP =  3220 ; TN =  25421 ; FN =  19577
# F1 = 0.43826232658995146
# Accuracy = 0.6008299627042076
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9886004539242353
# (57111, 30)
# TP =  8803 ; FP =  3429 ; TN =  25160 ; FN =  19719
# F1 = 0.4320066741914904
# Accuracy = 0.5946840363502652
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9885619237457545
# (57111, 30)
# TP =  8732 ; FP =  3358 ; TN =  25310 ; FN =  19711
# F1 = 0.43085880640465796
# Accuracy = 0.5960673075239445
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9887651659980831
# (57111, 30)
# TP =  8855 ; FP =  3333 ; TN =  25136 ; FN =  19787
# F1 = 0.4337496938525594
# Accuracy = 0.5951743096776453
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9932643760219685
# (57111, 30)
# TP =  8654 ; FP =  3466 ; TN =  25169 ; FN =  19822
# F1 = 0.4263474233914672
# Accuracy = 0.5922326697133652
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9935531077270543
# (57111, 30)
# TP =  8823 ; FP =  3378 ; TN =  25327 ; FN =  19583
# F1 = 0.43455561848942303
# Accuracy = 0.597958361786696
# ridge_regression
# (114222, 30)
# Ridge Regression: RMSE is  0.9934111937247807
# (57111, 30)
# TP =  8785 ; FP =  3459 ; TN =  25131 ; FN =  19736
# F1 = 0.4310069912915491
# Accuracy = 0.5938610775507346

# %%
#find parameters that maximize accuracy
results = pd.DataFrame(pd_filled_RR.loc[pd_filled_RR['acc'].idxmax()])
print(results)
out_w = results.iloc[[6]]
# Out:
#                                                            0
# acc                                                 0.600299
# degree                                                     0
# f1                                                  0.439515
# gamma                                                      0
# lambda                                                   0.5
# max_iters                                                  0
# out_w      [0.008326882430435978, -0.054468085343274346, ...
# rmse_te                                             0.960486
# rmse_tr                                             0.960756

# %%
accuracies = list(pd_filled_RR['acc'].values) 
plt.plot(lambdas,accuracies)
plt.ylabel('Accuracy')
plt.xlabel('lambdas')
plt.title('Accuracy ridge regression BALANCED')
plt.show()

# %%
DATA_TEST_PATH = r'C:/Users/Arthur Deleu/Documents/Documenten EPFL/Machine Learning/Project/project1/data/test.csv' # TODO: download train data and supply path here 
_, tx_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
OUTPUT_PATH = r'C:\Users\Arthur Deleu\Documents\Documenten EPFL\Machine Learning\Project\modellen\predictions_rr.csv' # TODO: fill in desired name of output file for submission
y_pred = predict_labels(out_w[0][0], tx_test)
create_csv_submission(ids_test, y_pred, OUTPUT_PATH)
# Out:
# [ 0.00832688 -0.05446809 -0.00264489  0.03118897  0.03347991  0.02831085
#  -0.02128858  0.00810085 -0.03585802  0.00825945 -0.02280305  0.05520715
#   0.04604641  0.02925884 -0.00094598 -0.00034276  0.00585093 -0.00024758
#   0.00057861  0.0164189   0.00299032 -0.00388781  0.0220023  -0.01351215
#   0.00152134  0.00179116 -0.01490003  0.00138571 -0.00139624  0.0022647 ]

# %%
w_ls, loss = opt_method(y_train, phi_train, initial_w, max_iters, gamma)
